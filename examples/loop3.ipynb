# %%
import sympy as sp
import control as ct
import pandas as pd
from mason.visualize import *
import matplotlib.pyplot as plt
from mason.solver import MasonSolver
from mason.adapters.control import *
s = sp.symbols("s")
df = pd.read_csv("../mason/tikz/ex2.8.csv")
solver = MasonSolver()

# %%
data = {
    "edges": [
        (row.start, row.end, sp.sympify(row.gain))
        for _, row in df.iterrows()
    ],
    "source": ["R"],
    "sink": ["C"],
}

# %%
data
# Out:
# {'edges': [('R', 'n1', 1),
#   ('n1', 'n2', G1),
#   ('n2', 'n3', 1),
#   ('n3', 'n4', G2),
#   ('n4', 'n5', 1),
#   ('n5', 'n6', G3),
#   ('n6', 'C', 1),
#   ('n5', 'n2', -H2),
#   ('n3', 'n1', -H1),
#   ('n6', 'n4', -H3)],
#  'source': ['R'],
#  'sink': ['C']}

# %%
solver.load_from_dict(data)

# %%
G,info = solver.transfer_function("R","C")

# %%
G
# Out:
# G1*G2*G3/(G1*G3*H1*H3 + G1*H1 + G2*H2 + G3*H3 + 1)

# %%
show_result(info)
# Out:
# $\displaystyle \textbf{Loops}$
# $\displaystyle \text{Loop } 1:\ n5 \rightarrow n6 \rightarrow n4 \rightarrow n5$
# $\displaystyle L_{1} = - G_{3} H_{3}$
# $\displaystyle \text{Loop } 2:\ n5 \rightarrow n2 \rightarrow n3 \rightarrow n4 \rightarrow n5$
# $\displaystyle L_{2} = - G_{2} H_{2}$
# $\displaystyle \text{Loop } 3:\ n1 \rightarrow n2 \rightarrow n3 \rightarrow n1$
# $\displaystyle L_{3} = - G_{1} H_{1}$
# $\displaystyle \textbf{Forward Paths}$
# $\displaystyle \text{Path } 1:\ R \rightarrow n1 \rightarrow n2 \rightarrow n3 \rightarrow n4 \rightarrow n5 \rightarrow n6 \rightarrow C$
# $\displaystyle P_1 = {G_{1} G_{2} G_{3}}$
# $\displaystyle \Delta_{1} = 1$
# $\displaystyle \textbf{System Determinant}$
# ...
