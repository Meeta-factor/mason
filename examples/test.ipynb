# %%
from mason.solver import MasonSolver,MIMOSFGSolver,ShannonHappSolver
solver = MIMOSFGSolver(MasonSolver)

data = {
    "edges": [
        ("R1", "C1", "G11"),
        ("R1", "C2", "G12"),
        ("R2", "C1", "G21"),
        ("R2", "C2", "G22"),
    ],
    "sources": ["R1", "R2"],
    "sinks": ["C1", "C2"],
}

solver.load_from_dict(data)

# %%
G,info = solver.transfer_matrix(
    sources=data["sources"],
    sinks=data["sinks"]
)

# %%
display(G)
# Out:
# Matrix([
# [G11, G21],
# [G12, G22]])

# %%
from mason.visualize import show_result
show_result(info,entry=("C1","R2"))
# Out:
# $\displaystyle \textbf{MIMO Transfer Matrix}$
# $\displaystyle G(s) = \left[\begin{matrix}G_{11} & G_{21}\\G_{12} & G_{22}\end{matrix}\right]$
# $\displaystyle \textbf{Selected Entry}: \ G_{12}(s) = C1 \leftarrow R2$
# $\displaystyle G_{12}(s) = G_{21}$
# $\displaystyle \textbf{Loops}$
# $\displaystyle \textbf{Forward Paths}$
# $\displaystyle \text{Path } 1:\ R2 \rightarrow C1$
# $\displaystyle P_1 = {G_{21}}$
# $\displaystyle \Delta_{1} = 1$
# $\displaystyle \textbf{System Determinant}$
# $\displaystyle \begin{aligned}\Delta &= 1 \\\\ &= 1 \\\\ &= 1\end{aligned}$
# $\displaystyle \textbf{Transfer Function}$
# $\displaystyle T = \frac{\sum P_i \Delta_i}{\Delta} = G_{21}$
