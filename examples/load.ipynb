# %%
from mason import MasonSolver,MIMOSFGSolver
from mason.visualize import *
import pandas as pd
import sympy as sp
df = pd.read_csv("../mason/tikz/load.csv")
solver = MIMOSFGSolver(entry_solver_cls=MasonSolver)

# %%
data = {
    "edges": [
        (row.start, row.end, sp.sympify(row.gain))
        for _, row in df.iterrows()
    ],
    "sources": ["PL1", "PL2","Pref1","Pref2"],
    "sinks": ["w1", "w2","P12","ACE1", "ACE2"],
}

# %%
solver.load_from_dict(data)

# %%
G11,info11 = solver.transfer_function("PL1","w1")

# %%
G11
# Out:
# -R1*s*(Tg1*s + 1)*(Tt1*s + 1)*(B2*KI2*R2*s + KI2*R2*T12 + R2*T12*s*(Tg2*s + 1)*(Tt2*s + 1) + R2*s**2*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + s**2)/(B1*B2*KI1*KI2*R1*R2*s + B1*KI1*R1*R2*T12*s*(Tg2*s + 1)*(Tt2*s + 1) + B1*KI1*R1*R2*s**2*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + B1*KI1*R1*s**2 + B2*KI2*R1*R2*T12*s*(Tg1*s + 1)*(Tt1*s + 1) + B2*KI2*R1*R2*s**2*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tt1*s + 1) + B2*KI2*R2*s**2 + KI1*KI2*R1*R2*T12*(B1 + B2) + KI1*R1*R2*T12*s*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + KI1*R1*T12*s + KI2*R1*R2*T12*s*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tt1*s + 1) + KI2*R2*T12*s + R1*R2*T12*s**2*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tg2*s + 1)*(Tt1*s + 1)*(Tt2*s + 1) + R1*R2*T12*s**2*(D2 + 2*H2*s)*(Tg1*s + 1)*(Tg2*s + 1)*(Tt1*s + 1)*(Tt2*s + 1) + R1*R2*s**3*(D1 + 2*H1*s)*(D2 + 2*H2*s)*(Tg1*s + 1)*(Tg2*s + 1)*(Tt1*s + 1)*(Tt2*s + 1) + R1*T12*s**2*(Tg1*s + 1)*(Tt1*s + 1) + R1*s**3*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tt1*s + 1) + R2*T12*s**2*(Tg2*s + 1)*(Tt2*s + 1) + R2*s**3*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + s**3)

# %%
show_result(info11)
# Out:
# $\displaystyle \textbf{Loops}$
# $\displaystyle \text{Loop } 1:\ Pv1 \rightarrow Pm1 \rightarrow X1 \rightarrow w1 \rightarrow U1 \rightarrow Pv1$
# $\displaystyle L_{1} = - \frac{1}{R_{1} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)}$
# $\displaystyle \text{Loop } 2:\ Pv1 \rightarrow Pm1 \rightarrow X1 \rightarrow w1 \rightarrow Dw12 \rightarrow P12 \rightarrow ACE1 \rightarrow Pref1 \rightarrow U1 \rightarrow Pv1$
# $\displaystyle L_{2} = - \frac{KI_{1} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)}$
# $\displaystyle \text{Loop } 3:\ Pv1 \rightarrow Pm1 \rightarrow X1 \rightarrow w1 \rightarrow ACE1 \rightarrow Pref1 \rightarrow U1 \rightarrow Pv1$
# $\displaystyle L_{3} = - \frac{B_{1} KI_{1}}{s \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)}$
# $\displaystyle \text{Loop } 4:\ Dw12 \rightarrow P12 \rightarrow X1 \rightarrow w1 \rightarrow Dw12$
# $\displaystyle L_{4} = - \frac{T_{12}}{s \left(D_{1} + 2 H_{1} s\right)}$
# $\displaystyle \text{Loop } 5:\ Dw12 \rightarrow P12 \rightarrow X2 \rightarrow w2 \rightarrow Dw12$
# $\displaystyle L_{5} = - \frac{T_{12}}{s \left(D_{2} + 2 H_{2} s\right)}$
# $\displaystyle \text{Loop } 6:\ Dw12 \rightarrow P12 \rightarrow ACE2 \rightarrow Pref2 \rightarrow U2 \rightarrow Pv2 \rightarrow Pm2 \rightarrow X2 \rightarrow w2 \rightarrow Dw12$
# $\displaystyle L_{6} = - \frac{KI_{2} T_{12}}{s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \text{Loop } 7:\ w2 \rightarrow U2 \rightarrow Pv2 \rightarrow Pm2 \rightarrow X2 \rightarrow w2$
# $\displaystyle L_{7} = - \frac{1}{R_{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \text{Loop } 8:\ w2 \rightarrow ACE2 \rightarrow Pref2 \rightarrow U2 \rightarrow Pv2 \rightarrow Pm2 \rightarrow X2 \rightarrow w2$
# $\displaystyle L_{8} = - \frac{B_{2} KI_{2}}{s \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \textbf{Forward Paths}$
# $\displaystyle \text{Path } 1:\ PL1 \rightarrow X1 \rightarrow w1$
# $\displaystyle P_1 = {- \frac{1}{D_{1} + 2 H_{1} s}}$
# $\displaystyle \Delta_{1} = \frac{B_{2} KI_{2} R_{2} s + KI_{2} R_{2} T_{12} + R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + s^{2}}{R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \textbf{System Determinant}$
# $\displaystyle \begin{aligned}\Delta &= 1 - \left(L_{1} + L_{2} + L_{3} + L_{4} + L_{5} + L_{6} + L_{7} + L_{8}\right) + \left(L_{1} \cdot L_{5} + L_{1} \cdot L_{6} + L_{1} \cdot L_{7} + L_{1} \cdot L_{8} + L_{2} \cdot L_{7} + L_{2} \cdot L_{8} + L_{3} \cdot L_{5} + L_{3} \cdot L_{6} + L_{3} \cdot L_{7} + L_{3} \cdot L_{8} + L_{4} \cdot L_{7} + L_{4} \cdot L_{8}\right) \\\\ &= 1 - \left(- \frac{1}{R_{1} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + - \frac{KI_{1} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + - \frac{B_{1} KI_{1}}{s \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + - \frac{T_{12}}{s \left(D_{1} + 2 H_{1} s\right)} + - \frac{T_{12}}{s \left(D_{2} + 2 H_{2} s\right)} + - \frac{KI_{2} T_{12}}{s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + - \frac{1}{R_{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + - \frac{B_{2} KI_{2}}{s \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}\right) + \left(\frac{T_{12}}{R_{1} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + \frac{KI_{2} T_{12}}{R_{1} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{1}{R_{1} R_{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{2} KI_{2}}{R_{1} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{KI_{1} T_{12}}{R_{2} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{2} KI_{1} KI_{2} T_{12}}{s^{3} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{1} KI_{1} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + \frac{B_{1} KI_{1} KI_{2} T_{12}}{s^{3} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{1} KI_{1}}{R_{2} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{1} B_{2} KI_{1} KI_{2}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{T_{12}}{R_{2} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{2} KI_{2} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}\right) \\\\ &= \frac{B_{1} B_{2} KI_{1} KI_{2} R_{1} R_{2} s + B_{1} KI_{1} R_{1} R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} s^{2} + B_{2} KI_{2} R_{1} R_{2} T_{12} s \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{1} R_{2} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{2} s^{2} + KI_{1} KI_{2} R_{1} R_{2} T_{12} \left(B_{1} + B_{2}\right) + KI_{1} R_{1} R_{2} T_{12} s \left(D_{2} + 2 H_{2} s\right) \ ...
# $\displaystyle \textbf{Transfer Function}$
# $\displaystyle T = \frac{\sum P_i \Delta_i}{\Delta} = - \frac{R_{1} s \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) \left(B_{2} KI_{2} R_{2} s + KI_{2} R_{2} T_{12} + R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + s^{2}\right)}{B_{1} B_{2} KI_{1} KI_{2} R_{1} R_{2} s + B_{1} KI_{1} R_{1} R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} s^{2} + B_{2} KI_{2} R_{1} R_{2} T_{12} s \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{1} R_{2} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{2} s^{2} + KI_{1} KI_{2} R_{1} R_{2} T_{12} \left(B_{1} + B_{2}\right) + KI_{1} R_{1} R_{2} T_{12} s \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + KI_{1} R_{1} T_{12} s + KI_{2} R_{1} R_{2} T_{12} s \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + KI_{2} R_{2} T_{12} s + R_{1} R_{2} T_{12} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right) + R_{1} R_{2} T_{12} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right) + R_{1} R_{2} s^{3} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right) + R_{1} T_{12} s^{2} \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + R_{1} s^{3} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + R_{2} T_{12} s^{2} \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + R_{2} s^{3} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + s^{3}}$
