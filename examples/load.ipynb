# %%
from mason import MasonSolver,MIMOSFGSolver
from mason.visualize import *
import pandas as pd
import sympy as sp
df = pd.read_csv("../mason/tikz/load.csv")
solver = MIMOSFGSolver(entry_solver_cls=MasonSolver)

# %%
data = {
    "edges": [
        (row.start, row.end, sp.sympify(row.gain))
        for _, row in df.iterrows()
    ],
    "sources": ["PL1", "PL2","Pref1","Pref2"],
    "sinks": ["w1", "w2","P12","ACE1", "ACE2"],
}

# %%
solver.load_from_dict(data)

# %%
G11,info11 = solver.transfer_function("PL1","w1")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 G11,info11 = solver.transfer_function("PL1","w1")
#
# File ~/Documents/pylab/mason/mason/solver.py:655, in MIMOSFGSolver.transfer_function(self, source, sink, expand_result, **kwargs)
#     647 solver = self.entry_solver_cls()
#     648 solver.load_from_dict(
#     649     {
#     650         "edges": list(self.data["edges"]),
#    (...)    653     }
#     654 )
# --> 655 return solver.transfer_function(
#     656     source,
#     657     sink,
#     658     expand_result=expand_result,
#     659     **kwargs,
#     660 )
#
# File ~/Documents/pylab/mason/mason/solver.py:364, in MasonSolver.transfer_function(self, source, sink, expand_result)
#     352 def transfer_function(
#     353     self,
#     354     source: Node,
#     355     sink: Node,
#     356     expand_result: bool = False
#     357 ) -> Tuple[Gain, Dict]:
#     358     """
#     359     返回总传递函数 T = Σ(Pk * Δk) / Δ。
#     360
#     361     同时返回一份 debug_info，便于把每条前向通路、每个回路以及
#     362     最终 Δ 的组成展示出来。
#     363     """
# --> 364     return super().transfer_function(source, sink, expand_result=expand_result)
#
# File ~/Documents/pylab/mason/mason/solver.py:241, in BaseSFGSolver.transfer_function(self, source, sink, expand_result)
#     238 if not paths:
#     239     raise ValueError(f"从 {source} 到 {sink} 没有前向通路")
# --> 241 delta = self.delta_from_loops(loops)
#     242 nt_groups = self.non_touching_loop_groups(loops)
#     244 delta_info = {
#     245     "single_loops": [
#     246         {
#    (...)    263     },
#     264 }
#
# File ~/Documents/pylab/mason/mason/solver.py:157, in BaseSFGSolver.delta_from_loops(self, loops)
#     154         term_sum += prod
#     155     delta = delta + term_sum if r % 2 == 0 else delta - term_sum
# --> 157 return sp.simplify(delta)
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/simplify/simplify.py:659, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     657 expr = Mul(*powsimp(expr).as_content_primitive())
#     658 _e = cancel(expr)
# --> 659 expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     660 expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#     662 if ratio is S.Infinity:
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/expr.py:3813, in Expr.cancel(self, *gens, **args)
#    3811 """See the cancel function in sympy.polys"""
#    3812 from sympy.polys.polytools import cancel
# -> 3813 return cancel(self, *gens, **args)
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/polys/polytools.py:7363, in cancel(f, _signsimp, *gens, **args)
#    7361     if f.is_Number or isinstance(f, Relational) or not isinstance(f, Expr):
#    7362         return f
# -> 7363     f = factor_terms(f, radical=True)
#    7364     p, q = f.as_numer_denom()
#    7366 elif len(f) == 2:
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:1271, in factor_terms(expr, radical, clear, fraction, sign)
#    1269     return rv
#    1270 expr2 = sympify(expr)
# -> 1271 return do(expr2)
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:1246, in factor_terms.<locals>.do(expr)
#    1244 cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1245 if p.is_Add:
# -> 1246     list_args = [do(a) for a in Add.make_args(p)]
#    1247     # get a common negative (if there) which gcd_terms does not remove
#    1248     if not any(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is None
#    1249                for a in list_args):
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:1267, in factor_terms.<locals>.do(expr)
#    1261     p = gcd_terms(p,
#    1262         isprimitive=True,
#    1263         clear=clear,
#    1264         fraction=fraction).xreplace(special)
#    1265 elif p.args:
#    1266     p = p.func(
# -> 1267         *[do(a) for a in p.args])
#    1268 rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1269 return rv
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:1234, in factor_terms.<locals>.do(expr)
#    1231 if expr.is_Pow or expr.is_Function or \
#    1232         is_iterable or not hasattr(expr, 'args_cnc'):
#    1233     args = expr.args
# -> 1234     newargs = tuple([do(i) for i in args])
#    1235     if newargs == args:
#    1236         return expr
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:1261, in factor_terms.<locals>.do(expr)
#    1259     # rebuild p not worrying about the order which gcd_terms will fix
#    1260     p = Add._from_args(list_args)
# -> 1261     p = gcd_terms(p,
#    1262         isprimitive=True,
#    1263         clear=clear,
#    1264         fraction=fraction).xreplace(special)
#    1265 elif p.args:
#    1266     p = p.func(
#    1267         *[do(a) for a in p.args])
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:1072, in gcd_terms(terms, isprimitive, clear, fraction)
#    1070     terms = sympify(terms)
#    1071 terms, reps = mask(terms)
# -> 1072 cont, numer, denom = _gcd_terms(terms, isprimitive, fraction)
#    1073 numer = numer.xreplace(reps)
#    1074 coeff, factors = cont.as_coeff_Mul()
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:957, in _gcd_terms(terms, isprimitive, fraction)
#     954     cont = cont.gcd(term)
#     956 for i, term in enumerate(terms):
# --> 957     terms[i] = term.quo(cont)
#     959 if fraction:
#     960     denom = terms[0].denom
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:872, in Term.quo(self, other)
#     871 def quo(self, other):  # Term
# --> 872     return self.mul(other.inv())
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:862, in Term.mul(self, other)
#     860 coeff = self.coeff*other.coeff
#     861 numer = self.numer.mul(other.numer)
# --> 862 denom = self.denom.mul(other.denom)
#     864 numer, denom = numer.normal(denom)
#     866 return Term(coeff, numer, denom)
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:488, in Factors.mul(self, other)
#     484             continue
#     486     factors[factor] = exp
# --> 488 return Factors(factors)
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/exprtools.py:328, in Factors.__init__(self, factors)
#     326 if isinstance(factors, Factors):
#     327     factors = factors.factors.copy()
# --> 328 elif factors in (None, S.One):
#     329     factors = {}
#     330 elif factors is S.Zero or factors == 0:
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/numbers.py:1970, in Integer.__eq__(self, other)
#    1968 elif isinstance(other, Integer):
#    1969     return (self.p == other.p)
# -> 1970 return Rational.__eq__(self, other)
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/numbers.py:1624, in Rational.__eq__(self, other)
#    1622 def __eq__(self, other):
#    1623     try:
# -> 1624         other = _sympify(other)
#    1625     except SympifyError:
#    1626         return NotImplemented
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/sympify.py:540, in _sympify(a)
#     514 def _sympify(a):
#     515     """
#     516     Short version of :func:`~.sympify` for internal usage for ``__add__`` and
#     517     ``__eq__`` methods where it is ok to allow some things (like Python
#    (...)    538
#     539     """
# --> 540     return sympify(a, strict=True)
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/sympify.py:422, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     420         conv = _sympy_converter.get(superclass)
#     421     if conv is not None:
# --> 422         return conv(a)
#     424 if cls is type(None):
#     425     if strict:
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/containers.py:337, in <lambda>(d)
#     334     __hash__ : Callable[[Basic], Any] = Basic.__hash__
#     336 # this handles dict, defaultdict, OrderedDict
# --> 337 _sympy_converter[dict] = lambda d: Dict(*d.items())
#     339 class OrderedSet(MutableSet):
#     340     def __init__(self, iterable=None):
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/containers.py:264, in Dict.__new__(cls, *args)
#     262     items = [Tuple(k, v) for k, v in args[0].items()]
#     263 elif iterable(args) and all(len(arg) == 2 for arg in args):
# --> 264     items = [Tuple(k, v) for k, v in args]
#     265 else:
#     266     raise TypeError('Pass Dict args as Dict((k1, v1), ...) or Dict({k1: v1, ...})')
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/containers.py:57, in Tuple.__new__(cls, *args, **kwargs)
#      55 if kwargs.get('sympify', True):
#      56     args = (sympify(arg) for arg in args)
# ---> 57 obj = Basic.__new__(cls, *args)
#      58 return obj
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/containers.py:56, in <genexpr>(.0)
#      54 def __new__(cls, *args, **kwargs):
#      55     if kwargs.get('sympify', True):
# ---> 56         args = (sympify(arg) for arg in args)
#      57     obj = Basic.__new__(cls, *args)
#      58     return obj
#
# File ~/Documents/pylab/mason/.venv/lib/python3.13/site-packages/sympy/core/sympify.py:417, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     414 #Check if there exists a converter for any of the types in the mro
#     415 for superclass in getmro(cls):
#     416     #First check for user defined converters
# --> 417     conv = _external_converter.get(superclass)
#     418     if conv is None:
#     419         #if none exists, check for SymPy defined converters
#     420         conv = _sympy_converter.get(superclass)
#
# KeyboardInterrupt:

# %%
G11
# Out:
# -R1*s*(Tg1*s + 1)*(Tt1*s + 1)*(B2*KI2*R2*s + KI2*R2*T12 + R2*T12*s*(Tg2*s + 1)*(Tt2*s + 1) + R2*s**2*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + s**2)/(B1*B2*KI1*KI2*R1*R2*s + B1*KI1*R1*R2*T12*s*(Tg2*s + 1)*(Tt2*s + 1) + B1*KI1*R1*R2*s**2*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + B1*KI1*R1*s**2 + B2*KI2*R1*R2*T12*s*(Tg1*s + 1)*(Tt1*s + 1) + B2*KI2*R1*R2*s**2*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tt1*s + 1) + B2*KI2*R2*s**2 + KI1*KI2*R1*R2*T12*(B1 + B2) + KI1*R1*R2*T12*s*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + KI1*R1*T12*s + KI2*R1*R2*T12*s*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tt1*s + 1) + KI2*R2*T12*s + R1*R2*T12*s**2*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tg2*s + 1)*(Tt1*s + 1)*(Tt2*s + 1) + R1*R2*T12*s**2*(D2 + 2*H2*s)*(Tg1*s + 1)*(Tg2*s + 1)*(Tt1*s + 1)*(Tt2*s + 1) + R1*R2*s**3*(D1 + 2*H1*s)*(D2 + 2*H2*s)*(Tg1*s + 1)*(Tg2*s + 1)*(Tt1*s + 1)*(Tt2*s + 1) + R1*T12*s**2*(Tg1*s + 1)*(Tt1*s + 1) + R1*s**3*(D1 + 2*H1*s)*(Tg1*s + 1)*(Tt1*s + 1) + R2*T12*s**2*(Tg2*s + 1)*(Tt2*s + 1) + R2*s**3*(D2 + 2*H2*s)*(Tg2*s + 1)*(Tt2*s + 1) + s**3)

# %%
show_result(info11)
# Out:
# $\displaystyle \textbf{Loops}$
# $\displaystyle \text{Loop } 1:\ ACE1 \rightarrow Pref1 \rightarrow U1 \rightarrow Pv1 \rightarrow Pm1 \rightarrow X1 \rightarrow w1 \rightarrow Dw12 \rightarrow P12 \rightarrow ACE1$
# $\displaystyle L_{1} = - \frac{KI_{1} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)}$
# $\displaystyle \text{Loop } 2:\ ACE1 \rightarrow Pref1 \rightarrow U1 \rightarrow Pv1 \rightarrow Pm1 \rightarrow X1 \rightarrow w1 \rightarrow ACE1$
# $\displaystyle L_{2} = - \frac{B_{1} KI_{1}}{s \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)}$
# $\displaystyle \text{Loop } 3:\ Dw12 \rightarrow P12 \rightarrow X1 \rightarrow w1 \rightarrow Dw12$
# $\displaystyle L_{3} = - \frac{T_{12}}{s \left(D_{1} + 2 H_{1} s\right)}$
# $\displaystyle \text{Loop } 4:\ Dw12 \rightarrow P12 \rightarrow X2 \rightarrow w2 \rightarrow Dw12$
# $\displaystyle L_{4} = - \frac{T_{12}}{s \left(D_{2} + 2 H_{2} s\right)}$
# $\displaystyle \text{Loop } 5:\ Dw12 \rightarrow P12 \rightarrow ACE2 \rightarrow Pref2 \rightarrow U2 \rightarrow Pv2 \rightarrow Pm2 \rightarrow X2 \rightarrow w2 \rightarrow Dw12$
# $\displaystyle L_{5} = - \frac{KI_{2} T_{12}}{s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \text{Loop } 6:\ ACE2 \rightarrow Pref2 \rightarrow U2 \rightarrow Pv2 \rightarrow Pm2 \rightarrow X2 \rightarrow w2 \rightarrow ACE2$
# $\displaystyle L_{6} = - \frac{B_{2} KI_{2}}{s \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \text{Loop } 7:\ Pm2 \rightarrow X2 \rightarrow w2 \rightarrow U2 \rightarrow Pv2 \rightarrow Pm2$
# $\displaystyle L_{7} = - \frac{1}{R_{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \text{Loop } 8:\ Pm1 \rightarrow X1 \rightarrow w1 \rightarrow U1 \rightarrow Pv1 \rightarrow Pm1$
# $\displaystyle L_{8} = - \frac{1}{R_{1} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)}$
# $\displaystyle \textbf{Forward Paths}$
# $\displaystyle \text{Path } 1:\ PL1 \rightarrow X1 \rightarrow w1$
# $\displaystyle P_1 = {- \frac{1}{D_{1} + 2 H_{1} s}}$
# $\displaystyle \Delta_{1} = \frac{B_{2} KI_{2} R_{2} s + KI_{2} R_{2} T_{12} + R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + s^{2}}{R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)}$
# $\displaystyle \textbf{System Determinant}$
# $\displaystyle \begin{aligned}\Delta &= 1 - \left(L_{1} + L_{2} + L_{3} + L_{4} + L_{5} + L_{6} + L_{7} + L_{8}\right) + \left(L_{1} \cdot L_{6} + L_{1} \cdot L_{7} + L_{2} \cdot L_{4} + L_{2} \cdot L_{5} + L_{2} \cdot L_{6} + L_{2} \cdot L_{7} + L_{3} \cdot L_{6} + L_{3} \cdot L_{7} + L_{4} \cdot L_{8} + L_{5} \cdot L_{8} + L_{6} \cdot L_{8} + L_{7} \cdot L_{8}\right) \\\\ &= 1 - \left(- \frac{KI_{1} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + - \frac{B_{1} KI_{1}}{s \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + - \frac{T_{12}}{s \left(D_{1} + 2 H_{1} s\right)} + - \frac{T_{12}}{s \left(D_{2} + 2 H_{2} s\right)} + - \frac{KI_{2} T_{12}}{s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + - \frac{B_{2} KI_{2}}{s \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + - \frac{1}{R_{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + - \frac{1}{R_{1} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)}\right) + \left(\frac{B_{2} KI_{1} KI_{2} T_{12}}{s^{3} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{KI_{1} T_{12}}{R_{2} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{1} KI_{1} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + \frac{B_{1} KI_{1} KI_{2} T_{12}}{s^{3} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{1} B_{2} KI_{1} KI_{2}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{1} KI_{1}}{R_{2} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{2} KI_{2} T_{12}}{s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{T_{12}}{R_{2} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{T_{12}}{R_{1} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right)} + \frac{KI_{2} T_{12}}{R_{1} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{B_{2} KI_{2}}{R_{1} s \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)} + \frac{1}{R_{1} R_{2} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right)}\right) \\\\ &= \frac{B_{1} B_{2} KI_{1} KI_{2} R_{1} R_{2} s + B_{1} KI_{1} R_{1} R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} s^{2} + B_{2} KI_{2} R_{1} R_{2} T_{12} s \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{1} R_{2} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{2} s^{2} + KI_{1} KI_{2} R_{1} R_{2} T_{12} \left(B_{1} + B_{2}\right) + KI_{1} R_{1} R_{2} T_{12} s \left(D_{2} + 2 H_{2} s\right) \ ...
# $\displaystyle \textbf{Transfer Function}$
# $\displaystyle T = \frac{\sum P_i \Delta_i}{\Delta} = - \frac{R_{1} s \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) \left(B_{2} KI_{2} R_{2} s + KI_{2} R_{2} T_{12} + R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + s^{2}\right)}{B_{1} B_{2} KI_{1} KI_{2} R_{1} R_{2} s + B_{1} KI_{1} R_{1} R_{2} T_{12} s \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} R_{2} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + B_{1} KI_{1} R_{1} s^{2} + B_{2} KI_{2} R_{1} R_{2} T_{12} s \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{1} R_{2} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + B_{2} KI_{2} R_{2} s^{2} + KI_{1} KI_{2} R_{1} R_{2} T_{12} \left(B_{1} + B_{2}\right) + KI_{1} R_{1} R_{2} T_{12} s \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + KI_{1} R_{1} T_{12} s + KI_{2} R_{1} R_{2} T_{12} s \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + KI_{2} R_{2} T_{12} s + R_{1} R_{2} T_{12} s^{2} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right) + R_{1} R_{2} T_{12} s^{2} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right) + R_{1} R_{2} s^{3} \left(D_{1} + 2 H_{1} s\right) \left(D_{2} + 2 H_{2} s\right) \left(Tg_{1} s + 1\right) \left(Tg_{2} s + 1\right) \left(Tt_{1} s + 1\right) \left(Tt_{2} s + 1\right) + R_{1} T_{12} s^{2} \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + R_{1} s^{3} \left(D_{1} + 2 H_{1} s\right) \left(Tg_{1} s + 1\right) \left(Tt_{1} s + 1\right) + R_{2} T_{12} s^{2} \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + R_{2} s^{3} \left(D_{2} + 2 H_{2} s\right) \left(Tg_{2} s + 1\right) \left(Tt_{2} s + 1\right) + s^{3}}$
